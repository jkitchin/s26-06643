# %% [markdown]
# # Assignment 5: Collaboration + CI/CD
#
# **Course:** 06-643 Scientific Software Engineering with AI Coding Agents
#
# **Topics covered:** L08 (GitHub Collaboration), L09 (CI/CD with GitHub Actions)
#
# In this assignment you will practice collaborative development workflows using GitHub and set up continuous integration for your `scholartools` package. The assignment has two components: a technical component (Parts 1–4) and a reflection (Part 5).

# %% [markdown]
# ## Part 1: GitHub Collaboration
#
# Push your `scholartools` package to GitHub (if you have not already done so), then use the branch-based collaboration workflow to add a new feature.
#
# 1. **Push to GitHub** — Make sure your repository is on GitHub and up to date with your latest work.
#
# 2. **Create a feature branch** — Branch off of `main` to develop a new feature. The feature can be anything meaningful: a new API endpoint, a new metric function, improved error handling, additional utility functions, etc.
#
# 3. **Open a Pull Request** on GitHub:
#    - Write a clear PR description (use AI to help draft it if you like).
#    - Include **what changed** and **why**.
#    - Link to any relevant issues.
#
# 4. **Show evidence** — Include a screenshot of or link to your PR below.

# %%
# Paste your git commands for creating the feature branch and pushing here
# Example:
# $ git checkout -b feature/new-endpoint
# $ git add ...
# $ git commit -m "feat: add journal impact endpoint"
# $ git push origin feature/new-endpoint

# %% [markdown]
# *Paste your PR screenshot or link here.*

# %% [markdown]
# ## Part 2: Code Review
#
# Exchange repository links with a classmate and perform a code review on each other's PRs. If you cannot coordinate with a classmate, you may use an AI coding agent to review your own PR.
#
# Your review should cover:
#
# 1. **Code quality** — Style, naming conventions, organization.
# 2. **Test coverage** — Are there tests for the new feature? Are edge cases handled?
# 3. **Documentation** — Are docstrings present? Is the README updated if needed?
# 4. **At least 3 substantive review comments** — Go beyond surface-level observations. Suggest improvements, ask clarifying questions, or point out potential issues.
#
# Show the review comments below (screenshots or copied text).

# %% [markdown]
# *Paste your review comments here (screenshots or text).*

# %% [markdown]
# ## Part 3: CI/CD with GitHub Actions
#
# Create a GitHub Actions workflow that automatically tests your package on every push and pull request.
#
# ### Requirements
#
# Create a file at `.github/workflows/ci.yml` in your repository with a workflow that:
#
# 1. **Triggers** on push to `main` and on pull requests.
# 2. **Tests on multiple Python versions**: 3.10, 3.11, and 3.12.
# 3. **Installs** the package and its dependencies.
# 4. **Runs pytest** with coverage reporting.
# 5. **Runs ruff** for linting.
#
# ### Deliverables
#
# - Show your workflow file contents below.
# - Show a screenshot of or link to a passing CI run (the Actions tab on GitHub).
# - If CI fails initially, show how you debugged and fixed it.

# %%
# Paste the contents of your .github/workflows/ci.yml here
# Example:
# name: CI
# on:
#   push:
#     branches: [main]
#   pull_request:
#     branches: [main]
# jobs:
#   test:
#     runs-on: ubuntu-latest
#     strategy:
#       matrix:
#         python-version: ["3.10", "3.11", "3.12"]
#     steps:
#       - uses: actions/checkout@v4
#       - name: Set up Python ${{ matrix.python-version }}
#         uses: actions/setup-python@v5
#         with:
#           python-version: ${{ matrix.python-version }}
#       - name: Install dependencies
#         run: |
#           pip install -e ".[dev]"
#       - name: Lint with ruff
#         run: ruff check .
#       - name: Test with pytest
#         run: pytest --cov

# %% [markdown]
# *Paste your CI run screenshot or link here. If CI failed initially, describe what went wrong and how you fixed it.*

# %% [markdown]
# ## Part 4: Merge and Tag
#
# Once CI passes and the review is complete:
#
# 1. **Merge the PR** on GitHub.
# 2. **Pull the merge** locally and **create a git tag** for a new version (e.g., `v0.2.0`).
# 3. **Show your final git log** with the merge visible.
#
# Paste your commands and output below.

# %%
# Paste your merge, tag, and log commands here
# Example:
# $ git checkout main
# $ git pull origin main
# $ git tag -a v0.2.0 -m "v0.2.0: add new feature"
# $ git push origin v0.2.0
# $ git log --oneline --graph

# %% [markdown]
# *Paste your `git log --oneline --graph` output here showing the merge.*

# %% [markdown]
# ## Part 5: Reflection
#
# Answer the following questions thoughtfully (a few sentences each).
#
# 1. How did the PR process change how you think about adding features?
#
# 2. What did you learn from reviewing someone else's code (or having AI review yours)?
#
# 3. What challenges did you face setting up CI/CD? How did AI help?
#
# 4. How does automated testing change your confidence in merging code?

# %% [markdown]
# *Your answers here.*
