# %% [markdown]
# # Assignment 2: API Package
#
# **Due:** Week 3
#
# **Points:** 6% of final grade
#
# ## Objective
#
# Build a complete Python package for the OpenAlex API using AI assistance.

# %% [markdown]
# ## Requirements
#
# Create a package called `scholartools` that:
#
# 1. **Functions** (use AI to generate):
#    - `search_works(query, limit=10)` - Search for papers
#    - `get_author(name)` - Get author info
#    - `calculate_h_index(citations)` - Calculate h-index
#
# 2. **Package Structure**:
#    - `pyproject.toml`
#    - `src/scholartools/__init__.py`
#    - `src/scholartools/api.py`
#    - `src/scholartools/metrics.py`
#    - `tests/test_api.py`
#    - `tests/test_metrics.py`
#    - `README.md`
#
# 3. **Quality**:
#    - Type hints on all functions
#    - Docstrings with examples
#    - Error handling
#    - At least 80% test coverage

# %% [markdown]
# ## Deliverables
#
# 1. **GitHub Repository**: Link to your package repo
# 2. **Demo**: Show the package working in this notebook
# 3. **Reflection**: Document your AI collaboration

# %% [markdown]
# ## Part 1: Package Demo
#
# After installing your package, demonstrate it works:

# %%
# Install your package (update path)
# !pip install -e /path/to/scholartools

# %%
# Demo: Search works

# %%
# Demo: Get author

# %%
# Demo: Calculate h-index

# %% [markdown]
# ## Part 2: Test Results

# %%
# Run tests and show coverage
# !cd /path/to/scholartools && pytest --cov

# %% [markdown]
# ## Part 3: Reflection
#
# ### AI Usage Log
#
# Document how you used AI for each component:
#
# | Component | AI Used For | Modifications Made |
# |-----------|-------------|--------------------|
# | pyproject.toml | | |
# | api.py | | |
# | metrics.py | | |
# | tests | | |
# | README | | |
#
# ### Questions
#
# 1. What was the most effective prompt you used?
#
# 2. What AI-generated code did you have to fix? Why?
#
# 3. What would you do differently next time?
