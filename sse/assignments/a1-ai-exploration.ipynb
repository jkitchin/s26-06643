# %% [markdown]
# # Assignment 1: AI Tool Exploration
#
# **Due:** Week 2
#
# **Points:** 6% of final grade
#
# ## Objective
#
# Compare different AI coding tools on the same task to understand their strengths and limitations.

# %% [markdown]
# ## Task
#
# Use **at least two** different AI coding tools to complete the following:
#
# Create a Python function that:
# 1. Takes a list of integers
# 2. Returns a dictionary with:
#    - `mean`: arithmetic mean
#    - `median`: middle value
#    - `mode`: most common value(s)
#    - `std`: standard deviation
# 3. Handles edge cases (empty list, single element)
# 4. Includes type hints and docstring
#
# ### Tools to Try
#
# Choose at least two:
# - Claude Code
# - GitHub Copilot
# - ChatGPT
# - Cursor
# - Other AI coding tool

# %% [markdown]
# ## Part 1: Tool A (3 points)
#
# ### Tool Used: [Name]
#
# ### Prompt Used:
#
# ```
# [Paste your prompt here]
# ```
#
# ### Generated Code:

# %%
# Paste the AI-generated code here

# %% [markdown]
# ### Testing:

# %%
# Test the function
# Add your test cases

# %% [markdown]
# ### Issues Found:
#
# - [ ] Does it handle empty list?
# - [ ] Does it handle single element?
# - [ ] Are type hints correct?
# - [ ] Is the docstring complete?
# - [ ] Any bugs?

# %% [markdown]
# ## Part 2: Tool B (3 points)
#
# ### Tool Used: [Name]
#
# [Repeat the same structure as Part 1]

# %% [markdown]
# ## Part 3: Reflection (Required)
#
# Answer the following questions:
#
# ### 1. Comparison
#
# How did the tools differ in:
# - Quality of generated code?
# - Handling of edge cases?
# - Code style and organization?
# - Response to follow-up prompts?
#
# *Your answer:*
#
# ### 2. Prompting
#
# Did you need to refine your prompt? What worked well?
#
# *Your answer:*
#
# ### 3. Trust
#
# What did you verify before trusting the AI output?
#
# *Your answer:*
#
# ### 4. Learning
#
# What would you do differently next time?
#
# *Your answer:*
